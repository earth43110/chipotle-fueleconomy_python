# %%
import pandas as pd

# %%
chipotle = pd.read_csv('chipotle.tsv', sep='\t')

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#this is a pandas dataframe
#essentially it is a table it's just called a dataframe here
type(chipotle)
# Out:
# pandas.core.frame.DataFrame

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
chipotle.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipotle.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipotle.index.values
# Out:
# array([   0,    1,    2, ..., 4619, 4620, 4621], dtype=int64)

# %%
chipotle.loc[[0,4,7]]
# Out:
#    order_id  quantity                     item_name  \
# 0         1         1  Chips and Fresh Tomato Salsa
# 4         2         2                  Chicken Bowl
# 7         4         1                 Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75

# %%
chipotle.loc[[0,4,7],["item_name","item_price"]]
# Out:
#                       item_name item_price
# 0  Chips and Fresh Tomato Salsa     $2.39
# 4                  Chicken Bowl    $16.98
# 7                 Steak Burrito    $11.75

# %%
#find all the rows where the order is a chicken salad bowl
chipotle["item_name"] == "Chicken Salad Bowl"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# Name: item_name, Length: 4622, dtype: bool

# %%
#returns only where row is true, or where name is chicken salad bowl
chipotle[chipotle["item_name"] == "Chicken Salad Bowl"]
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4561      1813         2  Chicken Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 256   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 315             [Fresh Tomato Salsa, Fajita Vegetables]    $17.50
# ...

# %%
(chipotle["quantity"] == 2) & (chipotle["item_name"] == "Chicken Salad Bowl")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Length: 4622, dtype: bool

# %%
chipotle[(chipotle["quantity"] == 2) & (chipotle["item_name"] == "Chicken Salad Bowl")]
# Out:
#       order_id  quantity           item_name  \
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# 591        243         2  Chicken Salad Bowl
# 633        261         2  Chicken Salad Bowl
# 816        337         2  Chicken Salad Bowl
# 864        357         2  Chicken Salad Bowl
# 1110       459         2  Chicken Salad Bowl
# 1923       777         2  Chicken Salad Bowl
# 2419       960         2  Chicken Salad Bowl
# 3167      1265         2  Chicken Salad Bowl
# 3507      1409         2  Chicken Salad Bowl
# 4561      1813         2  Chicken Salad Bowl
#
#                                      choice_description item_price
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 315             [Fresh Tomato Salsa, Fajita Vegetables]    $17.50
# ...

# %%
chipotle.sort_values(by='item_price')
# Out:
#       order_id  quantity            item_name  \
# 261        113         1          Canned Soda
# 1805       730         1          Canned Soda
# 1030       424         1          Canned Soda
# 3020      1201         1          Canned Soda
# 3021      1201         1        Bottled Water
# ...        ...       ...                  ...
# 4547      1807         1     Steak Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
#
#                                      choice_description item_price
# 261                                      [Mountain Dew]     $1.09
# 1805                                           [Sprite]     $1.09
# 1030                                  [Diet Dr. Pepper]     $1.09
# 3020                                  [Diet Dr. Pepper]     $1.09
# 3021                                                NaN     $1.09
# ...

# %%
chipotle.sort_values(by='item_price',ascending=False)
# Out:
#       order_id  quantity            item_name  \
# 2624      1042         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# ...        ...       ...                  ...
# 3145      1254         1          Canned Soda
# 414        180         1          Canned Soda
# 3162      1262         1          Canned Soda
# 821        338         1          Canned Soda
# 1457       591         1          Canned Soda
#
#                                      choice_description item_price
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
# 4419  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4036  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39
# 1825  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 3115  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.39
# ...

# %%
chipotle.sort_index()
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Exercise
chipotle[(chipotle["quantity"] == 3) & (chipotle["item_name"] == "Chicken Burrito")]
# Out:
#       order_id  quantity        item_name          choice_description  \
# 3634      1454         3  Chicken Burrito        [Fresh Tomato Salsa]
# 3636      1454         3  Chicken Burrito  [Fresh Tomato Salsa, Rice]
#
#      item_price
# 3634    $26.25
# 3636    $26.25

# %%
chipotle[chipotle["quantity"] == 4]
# Out:
#       order_id  quantity                     item_name  \
# 1254       511         4               Chicken Burrito
# 1257       511         4  Chips and Fresh Tomato Salsa
# 1425       577         4                 Bottled Water
# 1880       759         4                 Bottled Water
# 2235       901         4                   Canned Soda
# 3602      1443         4               Chicken Burrito
# 3973      1592         4             Canned Soft Drink
# 4489      1786         4           Chips and Guacamole
# 4490      1786         4             Canned Soft Drink
# 4491      1786         4             Canned Soft Drink
#
#                                      choice_description item_price
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# 1257                                                NaN    $11.80
# 1425                                                NaN     $6.00
# 1880                                                NaN     $6.00
# ...

# %%
chipotle.groupby(["item_name"]).sum("quantity")
# Out:
#                                        order_id  quantity
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# ...
